# %%
import numpy as np
from PIL import Image
import os

# %%
import pandas as pd

# %%
path = "./../../data/mnist_images"

# %%
train_test_folder = os.listdir(path)
train_path = path+"/"+train_test_folder[0]
test_path = path+"/"+train_test_folder[1]

train_digit_image_folders = os.listdir(train_path)
train_digit_image_folders.sort()

test_digit_image_folders = os.listdir(test_path)
test_digit_image_folders.sort()

# %%
all_threes_path = train_path+"/"+train_digit_image_folders[3]
all_threes = os.listdir(all_threes_path)
im3_path = all_threes_path+"/"+all_threes[1]
im3 = Image.open(im3_path)
im3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=28x28 at 0x7F8A2A325EB0>

# %%
im3_arr = np.array(im3)
df = pd.DataFrame(im3_arr[:15,:22])
df.style.set_properties(**{'font-size':'6pt'}).background_gradient('Greys')
# Out:
# <style  type="text/css" >
# #T_4e8c8_row0_col0,#T_4e8c8_row2_col4{
#             font-size:  6pt;
#             background-color:  #515151;
#             color:  #f1f1f1;
#         }#T_4e8c8_row0_col1,#T_4e8c8_row14_col14,#T_4e8c8_row14_col15{
#             font-size:  6pt;
#             background-color:  #828282;
#             color:  #000000;
# ...
